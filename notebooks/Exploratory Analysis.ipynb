# %% [markdown]
# # Exploratory analysis of training dataset
#
# This notebook's purpose is to show exploratory analysis approaches for regression problems

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns


from pylab import rcParams
from heatmap import heatmap, corrplot

import warnings
warnings.simplefilter('ignore')

sns.set(color_codes=True, font_scale=1.2)
rcParams['figure.figsize'] = 7,7 

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Import data

# %%
dataset = pd.read_csv("../data/pre-processed/train.csv")

# %% [markdown]
# #  Training data exploratory analysis

# %% [markdown]
# ## Target study

# %%
dataset["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,7))
fig.suptitle("House Sale Price")
# ax1.set_xticklabels(["SalePrice"])
ax1.boxplot(dataset["SalePrice"], notch=True, )
ax2.hist(dataset["SalePrice"], bins=50)
# Out:
# (array([  5.,  11.,  13.,  61.,  58., 126., 165., 180., 122., 130., 121.,
#          78.,  61.,  64.,  49.,  36.,  36.,  25.,  13.,  25.,  16.,  11.,
#           4.,  11.,   9.,   5.,   4.,   4.,   4.,   2.,   1.,   1.,   1.,
#           0.,   1.,   0.,   2.,   0.,   1.,   0.,   2.,   0.,   0.,   0.,
#           0.,   0.,   0.,   0.,   0.,   2.]),
#  array([ 34900.,  49302.,  63704.,  78106.,  92508., 106910., 121312.,
#         135714., 150116., 164518., 178920., 193322., 207724., 222126.,
#         236528., 250930., 265332., 279734., 294136., 308538., 322940.,
#         337342., 351744., 366146., 380548., 394950., 409352., 423754.,
#         438156., 452558., 466960., 481362., 495764., 510166., 524568.,
#         538970., 553372., 567774., 582176., 596578., 610980., 625382.,
#         639784., 654186., 668588., 682990., 697392., 711794., 726196.,
#         740598., 755000.]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ### Distribution of Target variable

# %% [markdown]
# # Covariance study

# %%
print(train_data.shape)
nrow = train_data.shape[0]
ncol = train_data.shape[1]
print(ncol)

plt.figure(figsize=(ncol, ncol))
#corrplot(train_data.corr(), size_scale=500);
sns.heatmap(train_data.corr())
